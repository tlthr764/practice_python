# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\hp\anaconda3\lib\site-packages (0.15.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\hp\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)

# %%
import folium

# %%
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15)

# %%
folium.Marker([37.547631,126.942463]).add_to(m)
folium.Marker([37.54392611998678,126.95105440539045],popup='subway').add_to(m)
folium.Marker([37.53959008903884,126.94590610865076],popup='subway',tooltip='마포역').add_to(m)
#공덕역
folium.Marker([37.54392611998678, 126.95105440539045], popup='subway', icon=folium.Icon(color='black', icon='info-sign')).add_to(m)
#마포역
folium.Marker([37.53959008903884, 126.94590610865076], popup='subway', tooltip='마포역', icon=folium.Icon(color='lightblue', icon='fa-solid fa-train-subway', prefix='fa-solid')).add_to(m)
m.add_child(folium.ClickForMarker(popup='클릭'))
m.add_child(folium.LatLngPopup())
# CircleMarker
folium.CircleMarker([37.54392611998678, 126.95105440539045], radius=100, color='#34EBC6', fill_color='blue', popup='CircleMarker', tooltip='tooltip').add_to(m)
# Circle
folium.Circle([37.54392611998678, 126.95105440539045], radius=100, color='#EB9E34', fill_color='red', popup='Circle', tooltip='tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d93688d6176f1a28e75cfd09f402d0e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d93688d6176f1a28e75cfd09f402d0e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d93688d6176f1a28e75cfd09f402d0e6 = L.map(
#                 &quot;map_d93688d6176f1a28e75cfd09f402d0e6&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_769d64c7d2a50fad07d73a9499579016 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_769d64c7d2a50fad07d73a9499579016.addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#             var marker_e11ba99385cfbefa5656f90beede5110 = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#             var marker_260dd9a52a6e7c0194cb84ce67e15b3d = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#             var marker_56b6c9476219647e481af56489152df1 = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#             var marker_710c390c280b090aeb8307cf3ec4e26d = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#         var popup_926f42901a42ef81e560e6b2068656a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d10cf1b10c9811650ee7aa08ae3b243f = $(`&lt;div id=&quot;html_d10cf1b10c9811650ee7aa08ae3b243f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_926f42901a42ef81e560e6b2068656a5.setContent(html_d10cf1b10c9811650ee7aa08ae3b243f);
#
#
#
#         marker_710c390c280b090aeb8307cf3ec4e26d.bindPopup(popup_926f42901a42ef81e560e6b2068656a5)
#         ;
#
#
#
#
#             var marker_b1ab768431acdb154c46c10ca10d38af = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#             var marker_fc1cad72df40799d7753e962b7e1e73a = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#         var popup_640117f157a322fe38a660b00cc16604 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea82877356a0b7c5e3aa2dc4db2c609e = $(`&lt;div id=&quot;html_ea82877356a0b7c5e3aa2dc4db2c609e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_640117f157a322fe38a660b00cc16604.setContent(html_ea82877356a0b7c5e3aa2dc4db2c609e);
#
#
#
#         marker_fc1cad72df40799d7753e962b7e1e73a.bindPopup(popup_640117f157a322fe38a660b00cc16604)
#         ;
#
#
#
#
#             var marker_34ec1b84cec2e5909f200378d64090db = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#         var popup_c3ae2158e229a78e1364199e6ff7f547 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_088c9cc2fd2898bef00f73281bfbd214 = $(`&lt;div id=&quot;html_088c9cc2fd2898bef00f73281bfbd214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_c3ae2158e229a78e1364199e6ff7f547.setContent(html_088c9cc2fd2898bef00f73281bfbd214);
#
#
#
#         marker_34ec1b84cec2e5909f200378d64090db.bindPopup(popup_c3ae2158e229a78e1364199e6ff7f547)
#         ;
#
#
#
#
#             var marker_3dc2cc64142022870c59b52bfd078acd = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#             var marker_c2ebcd8d1a53c6101f45a286b0dcb977 = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_d93688d6176f1a28e75cfd09f402d0e6);
#
#
#         var popup_175809a93930e2abe7d4e400200bfbcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ab338e0383603d0e4c7c47ae01f214a = $(`&lt;div id=&quot;html_0ab338e0383603d0e4c7c47ae01f214a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_175809a93930e2abe7d4e400200bfbcf.setCont
