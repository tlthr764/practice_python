# %%
import requests

# %%
response = requests.get("https://shopping.naver.com/home")
html = response.text
print(html)
# Out:
# <!DOCTYPE html><html lang="ko"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover"/><title>네이버쇼핑</title><meta property="og:title" content="네이버쇼핑"/><meta property="og:image" content="https://shopv.pstatic.net/web/cnsv/m/im/ogtag/01_nshopping.png"/><meta property="og:description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="og:locale" content="ko_KR"/><meta property="og:type" content="website"/><link rel="shortcut icon" href="https://shopv.pstatic.net/web/r/20231115180046/_next/static/ico/favicon_shopping.ico"/><link rel="apple-touch-icon-precomposed" href="https://shopv.pstatic.net/web/r/20231115180046/_next/static/ico/favicon_shopping.ico"/><meta name="apple-mobile-web-app-title" content="네이버쇼핑"/><meta name="application-name" content="네이버쇼핑"/><link rel="stylesheet"
# ...

# %%
# !pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=a7fc9fce96adc521d71438134c88530aa11313afec18a08d8d94877620ee4eb2
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup
soup= BeautifulSoup(html,'html.parser')
soup.select_one('.home')
# Out:
# <div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_naver_27gfm _gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a><a class="_gnbHeader_link_npay_p3s_q _gnbHeader_link_wW48B N=a:GNB.naverpay" href="https://new-m.pay.naver.com/pcpay?page=1" title="네이버 아이디로 간편구매, 네이버페이"><span class="blind">네이버페이</span></a></div><div class="_gnbHeader_shopping_gnb_wrap
# ...

# %%
soup.select_one('#FIRST_LAYER_ID')
# Out:
# <div id="FIRST_LAYER_ID"></div>

# %%
soup.select_one('div > .home')
# Out:
# <div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_naver_27gfm _gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a><a class="_gnbHeader_link_npay_p3s_q _gnbHeader_link_wW48B N=a:GNB.naverpay" href="https://new-m.pay.naver.com/pcpay?page=1" title="네이버 아이디로 간편구매, 네이버페이"><span class="blind">네이버페이</span></a></div><div class="_gnbHeader_shopping_gnb_wrap
# ...

# %%
soup.select_one('div .home')
# Out:
# <div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_naver_27gfm _gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a><a class="_gnbHeader_link_npay_p3s_q _gnbHeader_link_wW48B N=a:GNB.naverpay" href="https://new-m.pay.naver.com/pcpay?page=1" title="네이버 아이디로 간편구매, 네이버페이"><span class="blind">네이버페이</span></a></div><div class="_gnbHeader_shopping_gnb_wrap
# ...

# %%
soup.select('categoryResponsive_category__26dMl')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\HP\Desktop\python_coding\53_데이터크롤링\example.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/python_coding/53_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%81%AC%EB%A1%A4%EB%A7%81/example.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> soup.select('categoryResponsive_category__26dMl')[6]
#
# IndexError: list index out of range

# %%
soup.select_one('N=a:hom.cate3 categoryResponsive_link__rq9HW')['href']
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# c:\Users\HP\Desktop\python_coding\53_데이터크롤링\example.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/python_coding/53_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%81%AC%EB%A1%A4%EB%A7%81/example.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> soup.select_one('N=a:hom.cate3 categoryResponsive_link__rq9HW')['href']
#
# File c:\Users\HP\anaconda3\Lib\site-packages\bs4\element.py:2089, in Tag.select_one(self, selector, namespaces, **kwargs)
#    2073 def select_one(self, selector, namespaces=None, **kwargs):
#    2074     """Perform a CSS selection operation on the current element.
#    2075
#    2076     :param selector: A CSS selector.
#    (...)
#    2087     :rtype: bs4.element.Tag
#    2088     """
# -> 2089     return self.css.select_one(selector, namespaces, **kwargs)
#
# ...
