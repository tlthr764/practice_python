# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

service = Service(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=chrome_options)
driver.get("https://shopping.naver.com/home")

sleep(3)
search = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div > div._combineHeader_inner_2Uy4J > button > span')
search.click()
sleep(3)
input_elm = driver.find_element(By.CSS_SELECTOR, '#input_text')
input_elm.send_keys('자두')
input_elm.send_keys(Keys.RETURN)
sleep(3)

current_height = driver.execute_script("return window.scrollY")

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    current_height = scrolled_height

products = driver.find_elements(By.CSS_SELECTOR, '.product_list_item__b84TO')

for product in products:
    title = product.find_element(By.CSS_SELECTOR, '.product_info_tit__c5_pb').text
    print(f"제목 {title}")
    price = product.find_element(By.CSS_SELECTOR, '.product_num__iQsWh').text
    print(f"가격 {price}")
    # link = product.find_element(By.TAG_NAME, 'a').get_attribute('href')
    link = product.find_element(By.XPATH, '//a[contains(text(), "상품 바로가기")]').get_attribute('href')
    print(f"링크 {link}")
# Out:
# 제목 꿀과즙 자두 대석 후무사 추희 피 체리자두 포모사 왕자두 켈시 하우스 임산부 제철과일
# 가격 19,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 고당도 프리미엄 노지 자두 당도보장
# 가격 70,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 김천 자두 추희 가을자두 2kg 4kg
# 가격 38,610원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 새콤달콤 대석 자두 김천 의성 후무사 추희자두 임산부과일 과일선물
# 가격 20,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 햇 자두 후무사 대석자두 추희 도담 왕자두
# 가격 2,900,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 딜라잇가든 냉동 자두 반태 1kg
# 가격 6,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 의성자두 후무사 대석 추희 로얄대석 도담 왕자두 복숭아 자두 2kg 은주네농원
# 가격 26,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 서양자두 국내산 푸룬 자두 1kg 냉동
# 가격 11,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 가을 추희 자두 2kg내외(140g내외)
# 가격 23,220원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 서양자두 국내산 푸룬 자두 1kg 냉동
# 가격 11,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 갤러리아 농부마음가을자두 추희품종 자두 5kg
# 가격 31,290원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 과일꾼 [한정기간판매]23년 수확 새콤달콤 햇 추황배 5kg
# 가격 13,520원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 딜라잇가든 냉동 자두 반태 1kg x 5
# 가격 28,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 (냉동)흥국 냉동 자두 슬라이스 1kg / 자두스무디
# 가격 12,500원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 체리맛과 자두맛이 나는 체리자두
# 가격 3,900,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 고당도 프리미엄 자두 1.6kg
# 가격 70,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 김천자두 추희 피자두 도담 후무사 대석 자두 포모사 왕 특 3kg
# 가격 70,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 거창 나디아 체리자두 1kg(대과/60g~100g내외)
# 가격 15,840원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 하우스자두(8~14입/팩)
# 가격 9,980원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 경북 김천 산지직송 새콤달콤 추희 자두 상 3kg
# 가격 29,310원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 [이안] 냉동 자두 반태 1kg / 하프컷 중국산
# 가격 5,600원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 [맛딜]새콤달콤 하우스 자두 중과 1kg
# 가격 18,530원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 자두 추희자두 피자두 가을자두 후무사자두
# 가격 58,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 [초록자연] 후무사 자두 5kg 왕왕 달콤 노지 왕자두
# 가격 73,720원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 올댓 푸룬자두 새콤새콤 푸룬 냉동자두 1kg
# 가격 13,860원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 김천 자두 대석 수박 추희 피자두
# 가격 3,900,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 자두 800g/팩 (산본점)
# 가격 7,980원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 [딜라잇가든]냉동 자두(반태) 1kg x 10
# 가격 57,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 최선규 농부의 자두 대석자두 후무사 왕자두 5kg
# 가격 99,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 경북의성 노지 자두 3kg/추희(특대과)
# 가격 33,480원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 서양자두(롱존) 특묘목 1주
# 가격 13,760원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 안동푸룬 생푸룬 푸룬생과 2kg 4kg
# 가격 37,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 경북의성 노지 자두 3kg/추희(대과)
# 가격 27,160원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 영화농산 특급 자두 김천 추희 종류 가격 대석
# 가격 609,000원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 경북 안동 생 푸룬자두 선물용 2kg
# 가격 36,900원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 청년마켓 특품 후무사 자두 제철과일 고당도 - UnKnown
# 가격 68,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 맛있는가 맛딜새콤달콤 하우스 자두 중과 1kg
# 가격 17,390원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 후무사자두(1.2kg/팩)
# 가격 11,980원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 하우스 자두 900g/중소과/21~30과 내외
# 가격 66,530원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
# 제목 꿀먹은 달코미 노지 햇 자두 1kg 소과 (25과내외)
# 가격 9,800원
# 링크 https://adcr.naver.com/adcr?x=ynmC4/NAVGn5ZhMFNhBU4v///w==...
